# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.data.loader import DataLoader
from src.features.feature_engineering import (
    FeatureEngineering,
)

# %%
loader = DataLoader()

df = loader.load()
# Out:
# 2026-07-12 02:33:34 | INFO     | CreditCardFraudAI | Validating dataset path.
# 2026-07-12 02:33:34 | INFO     | CreditCardFraudAI | Loading dataset from D:\technology\Diploma\upgrad\May-2025-Batch\capstone-project\CreditCardFraudAI\data\raw\creditcard.csv
# 2026-07-12 02:33:34 | INFO     | CreditCardFraudAI | Loading dataset from D:\technology\Diploma\upgrad\May-2025-Batch\capstone-project\CreditCardFraudAI\data\raw\creditcard.csv
# 2026-07-12 02:33:37 | INFO     | CreditCardFraudAI | Dataset loaded successfully.
# 2026-07-12 02:33:37 | INFO     | CreditCardFraudAI | Rows: 284807 | Columns: 31

# %%
engineer = FeatureEngineering()

X, y = engineer.transform(df)

print(engineer.summary())
# Out:
# 2026-07-12 02:33:47 | INFO     | CreditCardFraudAI | Preparing feature matrix and target vector.
# 2026-07-12 02:33:47 | INFO     | CreditCardFraudAI | Feature count : 30
# {'target_column': 'Class', 'feature_count': 30, 'feature_columns': ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']}
