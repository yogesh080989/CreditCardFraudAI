# %%
from pathlib import Path
import sys

# Find the project root (one level above notebooks/)
PROJECT_ROOT = Path.cwd().parent

# Add project root to Python path
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project Root:", PROJECT_ROOT)
from src.core.config import ConfigManager

config = ConfigManager()

print("Project Root :", config.project_root)
print("Config Path  :", config.config_path)
print("Exists       :", config.config_path.exists())
print("Dataset Path :", config.get("dataset_path"))
# Out:
# Project Root: d:\technology\Diploma\upgrad\May-2025-Batch\capstone-project\CreditCardFraudAI
# Project Root : D:\technology\Diploma\upgrad\May-2025-Batch\capstone-project\CreditCardFraudAI
# Config Path  : D:\technology\Diploma\upgrad\May-2025-Batch\capstone-project\CreditCardFraudAI\config\config.yaml
# Exists       : True
# Dataset Path : data/raw/creditcard.csv

# %%
from src.data.loader import DataLoader

loader = DataLoader()

print(loader.dataset_path)
print(loader.dataset_path.exists())
# Out:
# D:\technology\Diploma\upgrad\May-2025-Batch\capstone-project\CreditCardFraudAI\data\raw\creditcard.csv
# True

# %%
df = loader.load()

print(df.shape)
df.head()
# Out:
# 2026-07-12 01:06:28 | INFO     | CreditCardFraudAI | Validating dataset path.
# 2026-07-12 01:06:28 | INFO     | CreditCardFraudAI | Loading dataset from D:\technology\Diploma\upgrad\May-2025-Batch\capstone-project\CreditCardFraudAI\data\raw\creditcard.csv
# 2026-07-12 01:06:30 | INFO     | CreditCardFraudAI | Dataset loaded successfully.
# 2026-07-12 01:06:30 | INFO     | CreditCardFraudAI | Rows: 284807 | Columns: 31
# (284807, 31)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
# ...

# %%
from src.validation.profiler import DataProfiler

profiler = DataProfiler(df)

report = profiler.profile()

profiler.print_summary()
# Out:
# 2026-07-12 01:06:30 | INFO     | CreditCardFraudAI | Starting data profiling.
# 2026-07-12 01:06:32 | INFO     | CreditCardFraudAI | Data profiling completed.
# 2026-07-12 01:06:32 | INFO     | CreditCardFraudAI | Starting data profiling.
# 2026-07-12 01:06:36 | INFO     | CreditCardFraudAI | Data profiling completed.
# ========== DATA PROFILE ==========
# ...

# %%
from src.data.loader import DataLoader
from src.validation.validation_engine import ValidationEngine

loader = DataLoader()

df = loader.load()

engine = ValidationEngine(df)

report = engine.validate()

engine.print_summary()
# Out:
# 2026-07-12 01:06:36 | INFO     | CreditCardFraudAI | Validating dataset path.
# 2026-07-12 01:06:36 | INFO     | CreditCardFraudAI | Loading dataset from D:\technology\Diploma\upgrad\May-2025-Batch\capstone-project\CreditCardFraudAI\data\raw\creditcard.csv
# 2026-07-12 01:06:38 | INFO     | CreditCardFraudAI | Dataset loaded successfully.
# 2026-07-12 01:06:38 | INFO     | CreditCardFraudAI | Rows: 284807 | Columns: 31
# 2026-07-12 01:06:38 | INFO     | CreditCardFraudAI | Starting validation engine.
# 2026-07-12 01:06:38 | INFO     | CreditCardFraudAI | Running schema validation.
# 2026-07-12 01:06:38 | INFO     | CreditCardFraudAI | Running business rule validation.
# 2026-07-12 01:06:39 | INFO     | CreditCardFraudAI | Running data profiler.
# 2026-07-12 01:06:39 | INFO     | CreditCardFraudAI | Starting data profiling.
# 2026-07-12 01:06:42 | INFO     | CreditCardFraudAI | Data profiling completed.
# ...

# %%
from src.data.loader import DataLoader
from src.validation.validation_engine import ValidationEngine
from src.validation.report_generator import ReportGenerator

loader = DataLoader()

df = loader.load()

engine = ValidationEngine(df)

report = engine.validate()

generator = ReportGenerator()

generator.print_console(report)

generator.save_json(report)

generator.save_text(report)
# Out:
# 2026-07-12 01:12:32 | INFO     | CreditCardFraudAI | Validating dataset path.
# 2026-07-12 01:12:32 | INFO     | CreditCardFraudAI | Loading dataset from D:\technology\Diploma\upgrad\May-2025-Batch\capstone-project\CreditCardFraudAI\data\raw\creditcard.csv
# 2026-07-12 01:12:33 | INFO     | CreditCardFraudAI | Dataset loaded successfully.
# 2026-07-12 01:12:33 | INFO     | CreditCardFraudAI | Rows: 284807 | Columns: 31
# 2026-07-12 01:12:33 | INFO     | CreditCardFraudAI | Starting validation engine.
# 2026-07-12 01:12:33 | INFO     | CreditCardFraudAI | Running schema validation.
# 2026-07-12 01:12:33 | INFO     | CreditCardFraudAI | Running business rule validation.
# 2026-07-12 01:12:34 | INFO     | CreditCardFraudAI | Running data profiler.
# 2026-07-12 01:12:34 | INFO     | CreditCardFraudAI | Starting data profiling.
# 2026-07-12 01:12:36 | INFO     | CreditCardFraudAI | Data profiling completed.
# ...
